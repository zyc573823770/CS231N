# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.383025
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 3.116965 analytic: 3.116965, relative error: 2.158623e-08
# numerical: 3.442349 analytic: 3.442348, relative error: 2.354370e-08
# numerical: 0.572221 analytic: 0.572221, relative error: 2.269486e-08
# numerical: -0.012676 analytic: -0.012676, relative error: 4.023384e-06
# numerical: 0.496168 analytic: 0.496168, relative error: 2.128130e-08
# numerical: 1.594339 analytic: 1.594339, relative error: 3.348594e-08
# numerical: 2.269320 analytic: 2.269320, relative error: 4.450441e-08
# numerical: 1.981330 analytic: 1.981330, relative error: 1.466477e-08
# numerical: 0.453069 analytic: 0.453069, relative error: 1.829537e-07
# numerical: 1.487945 analytic: 1.487945, relative error: 1.042950e-08
# numerical: 2.020188 analytic: 2.020187, relative error: 2.106951e-08
# numerical: 2.566594 analytic: 2.566594, relative error: 3.073201e-08
# numerical: -1.487572 analytic: -1.487572, relative error: 1.000815e-08
# numerical: 0.374777 analytic: 0.374777, relative error: 8.001734e-08
# numerical: 3.293206 analytic: 3.293206, relative error: 9.588565e-09
# numerical: -3.339197 analytic: -3.339197, relative error: 9.055720e-09
# numerical: 0.743367 analytic: 0.743367, relative error: 3.980213e-08
# numerical: -0.017710 analytic: -0.017710, relative error: 7.030275e-07
# numerical: -0.765931 analytic: -0.765931, relative error: 1.365612e-08
# numerical: 0.114834 analytic: 0.114834, relative error: 7.651653e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.383025e+00 computed in 0.281161s
# vectorized loss: 2.383025e+00 computed in 0.012522s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
learning_rates = np.linspace(*learning_rates, 5)
regularization_strengths = np.linspace(*regularization_strengths, 6)
print(learning_rates)
print(regularization_strengths)
ite = 0
for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        ite += 1
        print("---------------------No.%diter-----------------------" % (ite))
        classifier = Softmax()
        classifier.train(X_train, y_train, 
                                learning_rate=learning_rate, 
                                reg=regularization_strength, 
                                num_iters=1500, 
                                batch_size=200, 
                                verbose=True)
        train_pred = classifier.predict(X_train)
        val_pred = classifier.predict(X_val)
        results[(learning_rate, regularization_strength)] = (np.mean(train_pred==y_train), np.mean(val_pred==y_val))
        if results[(learning_rate, regularization_strength)][1] > best_val:
            best_val = results[(learning_rate, regularization_strength)][1]
            best_softmax = classifier
        print("Choose lr = %e ,reg = %e" % (learning_rate, regularization_strength))
        print("Train acc = %f, Val acc = %f" % (results[(learning_rate, regularization_strength)][0], results[(learning_rate, regularization_strength)][1]))

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 9416
# iteration 800 / 1500: loss 2.099113
# iteration 900 / 1500: loss 2.079303
# iteration 1000 / 1500: loss 2.168044
# iteration 1100 / 1500: loss 2.109325
# iteration 1200 / 1500: loss 2.129144
# iteration 1300 / 1500: loss 2.144879
# iteration 1400 / 1500: loss 2.070919
# Choose lr = 1.000000e-07 ,reg = 4.500000e+04
# Train acc = 0.305714, Val acc = 0.319000
# ---------------------No.6iter-----------------------
# iteration 0 / 1500: loss 1537.669876
# iteration 100 / 1500: loss 207.068270
# iteration 200 / 1500: loss 29.522547
# iteration 300 / 1500: loss 5.808655
# iteration 400 / 1500: loss 2.635368
# iteration 500 / 1500: loss 2.235084
# iteration 600 / 1500: loss 2.134914
# iteration 700 / 1500: loss 2.142317
# iteration 800 / 1500: loss 2.147277
# iteration 900 / 1500: loss 2.152588
# iteration 1000 / 1500: loss 2.161822
# iteration 1100 / 1500: loss 2.163222
# iteration 1200 / 1500: loss 2.153390
# iteration 1300 / 1500: loss 2.141331
# iteration 1400 / 1500: loss 2.134336
# Choose lr = 1.000000e-07 ,reg = 5.000000e+04
# Train acc = 0.304490, Val acc = 0.316000
# ---------------------No.7iter-----------------------
# iteration 0 / 1500: loss 780.784771
# iteration 100 / 1500: loss 105.648393
# iteration 200 / 1500: loss 15.837487
# iteration 300 / 1500: loss 3.936069
# iteration 400 / 1500: loss 2.358569
# iteration 500 / 1500: loss 2.102996
# iteration 600 / 1500: loss 2.063104
# iteration 700 / 1500: loss 2.062815
# iteration 800 / 1500: loss 2.051110
# iteration 900 / 1500: loss 2.088009
# iteration 1000 / 1500: loss 2.067527
# iteration 1100 / 1500: loss 2.089380
# iteration 1200 / 1500: loss 2.051675
# iteration 1300 / 1500: loss 2.052833
# iteration 1400 / 1500: loss 2.118230
# Choose lr = 2.000000e-07 ,reg = 2.500000e+04
# Train acc = 0.330816, Val acc = 0.346000
# ---------------------No.8iter-----------------------
# iteration 0 / 1500: loss 923.497218
# iteration 100 / 1500: loss 83.945813
# iteration 200 / 1500: loss 9.405867
# iteration 300 / 1500: loss 2.757252
# iteration 400 / 1500: loss 2.119429
# iteration 500 / 1500: loss 2.084393
# iteration 600 / 1500: loss 2.093830
# iteration 700 / 1500: loss 2.107815
# iteration 800 / 1500: loss 2.044592
# iteration 900 / 1500: loss 2.047131
# iteration 1000 / 1500: loss 2.075244
# iteration 1100 / 1500: loss 2.117802
# iteration 1200 / 1500: loss 2.125526
# iteration 1300 / 1500: loss 2.064253
# iteration 1400 / 1500: loss 2.078813
# Choose lr = 2.000000e-07 ,reg = 3.000000e+04
# Train acc = 0.320184, Val acc = 0.343000
# ---------------------No.9iter-----------------------
# iteration 0 / 1500: loss 1082.174171
# iteration 100 / 1500: loss 65.969321
# iteration 200 / 1500: loss 5.898489
# iteration 300 / 1500: loss 2.326466
# iteration 400 / 1500: loss 2.138044
# iteration 500 / 1500: loss 2.105058
# iteration 600 / 1500: loss 2.110301
# iteration 700 / 1500: loss 2.143214
# iteration 800 / 1500: loss 2.098901
# iteration 900 / 1500: loss 2.057916
# iteration 1000 / 1500: loss 2.089030
# iteration 1100 / 1500: loss 2.120050
# iteration 1200 / 1500: loss 2.119156
# iteration 1300 / 1500: loss 2.181295
# iteration 1400 / 1500: loss 2.124620
# Choose lr = 2.000000e-07 ,reg = 3.500000e+04
# Train acc = 0.312633, Val acc = 0.333000
# ---------------------No.10iter-----------------------
# iteration 0 / 1500: loss 1239.196642
# iteration 100 / 1500: loss 50.930913
# iteration 200 / 1500: loss 4.038430
# iteration 300 / 1500: loss 2.173324
# iteration 400 / 1500: loss 2.135416
# iteration 500 / 1500: loss 2.153073
# iteration 600 / 1500: loss 2.156039
# iteration 700 / 1500: loss 2.105557
# iteration 800 / 1500: loss 2.105002
# iteration 900 / 1500: loss 2.113970
# iteration 1000 / 1500: loss 2.125279
# iteration 1100 / 1500: loss 2.093845
# iteration 1200 / 1500: loss 2.191243
# iteration 1300 / 1500: loss 2.180933
# iteration 1400 / 1500: loss 2.130806
# Choose lr = 2.000000e-07 ,reg = 4.000000e+04
# Train acc = 0.316184, Val acc = 0.337000
# ---------------------No.11iter-----------------------
# iteration 0 / 1500: loss 1376.592266
# iteration 100 / 1500: loss 38.232012
# iteration 200 / 1500: loss 3.034877
# iteration 300 / 1500: loss 2.098310
# iteration 400 / 1500: loss 2.181208
# iteration 500 / 1500: loss 2.119677
# iteration 600 / 1500: loss 2.077500
# iteration 700 / 1500: loss 2.156280
# iteration 800 / 1500: loss 2.151433
# iteration 900 / 1500: loss 2.094439
# iteration 1000 / 1500: loss 2.146421
# iteration 1100 / 1500: loss 2.145399
# iteration 1200 / 1500: loss 2.126144
# iteration 1300 / 1500: loss 2.124238
# iteration 1400 / 1500: loss 2.077848
# Choose lr = 2.000000e-07 ,reg = 4.500000e+04
# Train acc = 0.294449, Val acc = 0.310000
# ---------------------No.12iter-----------------------
# iteration 0 / 1500: loss 1551.339265
# iteration 100 / 1500: loss 29.240915
# iteration 200 / 1500: loss 2.582499
# iteration 300 / 1500: loss 2.167996
# iteration 400 / 1500: loss 2.122898
# iteration 500 / 1500: loss 2.136270
# iteration 600 / 1500: loss 2.141241
# iteration 700 / 1500: loss 2.101109
# iteration 800 / 1500: loss 2.129770
# iteration 900 / 1500: loss 2.167901
# iteration 1000 / 1500: loss 2.134625
# iteration 1100 / 1500: loss 2.116417
# iteration 1200 / 1500: loss 2.156613
# iteration 1300 / 1500: loss 2.139663
# iteration 1400 / 1500: loss 2.090303
# Choose lr = 2.000000e-07 ,reg = 5.000000e+04
# Train acc = 0.301510, Val acc = 0.314000
# ---------------------No.13iter-----------------------
# iteration 0 / 1500: loss 774.202332
# iteration 100 / 1500: loss 39.253611
# iteration 200 / 1500: loss 3.892120
# iteration 300 / 1500: loss 2.149572
# iteration 400 / 1500: loss 2.119092
# iteration 500 / 1500: loss 2.139376
# iteration 600 / 1500: loss 2.129718
# iteration 700 / 1500: loss 2.089111
# iteration 800 / 1500: loss 2.056243
# iteration 900 / 1500: loss 2.104699
# iteration 1000 / 1500: loss 2.103714
# iteration 1100 / 1500: loss 2.065103
# iteration 1200 / 1500: loss 2.088922
# iteration 1300 / 1500: loss 2.100765
# iteration 1400 / 1500: loss 2.085495
# Choose lr = 3.000000e-07 ,reg = 2.500000e+04
# Train acc = 0.328918, Val acc = 0.344000
# ---------------------No.14iter-----------------------
# iteration 0 / 1500: loss 927.212045
# iteration 100 / 1500: loss 26.345012
# iteration 200 / 1500: loss 2.722817
# iteration 300 / 1500: loss 2.078108
# iteration 400 / 1500: loss 2.103534
# iteration 500 / 1500: loss 2.099476
# iteration 600 / 1500: loss 2.113574
# iteration 700 / 1500: loss 2.128066
# iteration 800 / 1500: loss 2.072296
# iteration 900 / 1500: loss 2.057725
# iteration 1000 / 1500: loss 2.119753
# iteration 1100 / 1500: loss 2.105445
# iteration 1200 / 1500: loss 2.089987
# iteration 1300 / 1500: loss 2.084576
# iteration 1400 / 1500: loss 2.137564
# Choose lr = 3.000000e-07 ,reg = 3.000000e+04
# Train acc = 0.315265, Val acc = 0.329000
# ---------------------No.15iter-----------------------
# iteration 0 / 1500: loss 1080.447790
# iteration 100 / 1500: loss 17.409833
# iteration 200 / 1500: loss 2.306580
# iteration 300 / 1500: loss 2.109556
# iteration 400 / 1500: loss 2.109371
# iteration 500 / 1500: loss 2.135493
# iteration 600 / 1500: loss 2.152035
# iteration 700 / 1500: loss 2.143393
# iteration 800 / 1500: loss 2.105662
# iteration 900 / 1500: loss 2.098609
# iteration 1000 / 1500: loss 2.101876
# iteration 1100 / 1500: loss 2.128321
# iteration 1200 / 1500: loss 2.114507
# iteration 1300 / 1500: loss 2.144241
# iteration 1400 / 1500: loss 2.132090
# Choose lr = 3.000000e-07 ,reg = 3.500000e+04
# Train acc = 0.313592, Val acc = 0.325000
# ---------------------No.16iter-----------------------
# iteration 0 / 1500: loss 1239.820633
# iteration 100 / 1500: loss 11.656015
# iteration 200 / 1500: loss 2.170667
# iteration 300 / 1500: loss 2.136473
# iteration 400 / 1500: loss 2.193766
# iteration 500 / 1500: loss 2.153878
# iteration 600 / 1500: loss 2.107277
# iteration 700 / 1500: loss 2.046319
# iteration 800 / 1500: loss 2.155653
# iteration 900 / 1500: loss 2.144865
# iteration 1000 / 1500: loss 2.109929
# iteration 1100 / 1500: loss 2.197822
# iteration 1200 / 1500: loss 2.100733
# iteration 1300 / 1500: loss 2.089810
# iteration 1400 / 1500: loss 2.121332
# Choose lr = 3.000000e-07 ,reg = 4.000000e+04
# Train acc = 0.306796, Val acc = 0.326000
# ---------------------No.17iter-----------------------
# iteration 0 / 1500: loss 1390.439647
# iteration 100 / 1500: loss 7.915421
# iteration 200 / 1500: loss 2.125049
# iteration 300 / 1500: loss 2.151576
# iteration 400 / 1500: loss 2.143747
# iteration 500 / 1500: loss 2.098439
# iteration 600 / 1500: loss 2.105908
# iteration 700 / 1500: loss 2.159547
# iteration 800 / 1500: loss 2.159169
# iteration 900 / 1500: loss 2.162352
# iteration 1000 / 1500: loss 2.121760
# iteration 1100 / 1500: loss 2.163218
# iteration 1200 / 1500: loss 2.128007
# iteration 1300 / 1500: loss 2.130663
# iteration 1400 / 1500: loss 2.171725
# Choose lr = 3.000000e-07 ,reg = 4.500000e+04
# Train acc = 0.306184, Val acc = 0.325000
# ---------------------No.18iter-----------------------
# iteration 0 / 1500: loss 1570.244839
# iteration 100 / 1500: loss 5.688284
# iteration 200 / 1500: loss 2.140984
# iteration 300 / 1500: loss 2.088756
# iteration 400 / 1500: loss 2.083871
# iteration 500 / 1500: loss 2.122226
# iteration 600 / 1500: loss 2.148893
# iteration 700 / 1500: loss 2.133897
# iteration 800 / 1500: loss 2.144218
# iteration 900 / 1500: loss 2.152562
# iteration 1000 / 1500: loss 2.143167
# iteration 1100 / 1500: loss 2.172212
# iteration 1200 / 1500: loss 2.174406
# iteration 1300 / 1500: loss 2.100087
# iteration 1400 / 1500: loss 2.118962
# Choose lr = 3.000000e-07 ,reg = 5.000000e+04
# Train acc = 0.304571, Val acc = 0.323000
# ---------------------No.19iter-----------------------
# iteration 0 / 1500: loss 773.551765
# iteration 100 / 1500: loss 15.423261
# iteration 200 / 1500: loss 2.328107
# iteration 300 / 1500: loss 2.095730
# iteration 400 / 1500: loss 2.073173
# iteration 500 / 1500: loss 2.095755
# iteration 600 / 1500: loss 2.092048
# iteration 700 / 1500: loss 2.094322
# iteration 800 / 1500: loss 2.052431
# iteration 900 / 1500: loss 2.103368
# iteration 1000 / 1500: loss 2.094605
# iteration 1100 / 1500: loss 2.068504
# iteration 1200 / 1500: loss 2.166621
# iteration 1300 / 1500: loss 2.092701
# iteration 1400 / 1500: loss 2.117970
# Choose lr = 4.000000e-07 ,reg = 2.500000e+04
# Train acc = 0.324388, Val acc = 0.342000
# ---------------------No.20iter-----------------------
# iteration 0 / 1500: loss 930.801872
# iteration 100 / 1500: loss 9.241958
# iteration 200 / 1500: loss 2.135506
# iteration 300 / 1500: loss 2.127241
# iteration 400 / 1500: loss 2.101120
# iteration 500 / 1500: loss 2.133812
# iteration 600 / 1500: loss 2.100288
# iteration 700 / 1500: loss 2.079271
# iteration 800 / 1500: loss 2.078228
# iteration 900 / 1500: loss 2.080824
# iteration 1000 / 1500: loss 2.105591
# iteration 1100 / 1500: loss 2.083870
# iteration 1200 / 1500: loss 2.090436
# iteration 1300 / 1500: loss 2.116133
# iteration 1400 / 1500: loss 2.122497
# Choose lr = 4.000000e-07 ,reg = 3.000000e+04
# Train acc = 0.322020, Val acc = 0.337000
# ---------------------No.21iter-----------------------
# iteration 0 / 1500: loss 1090.738684
# iteration 100 / 1500: loss 5.794733
# iteration 200 / 1500: loss 2.150264
# iteration 300 / 1500: loss 2.116666
# iteration 400 / 1500: loss 2.108357
# iteration 500 / 1500: loss 2.117736
# iteration 600 / 1500: loss 2.124624
# iteration 700 / 1500: loss 2.109013
# iteration 800 / 1500: loss 2.078980
# iteration 900 / 1500: loss 2.140129
# iteration 1000 / 1500: loss 2.078110
# iteration 1100 / 1500: loss 2.087368
# iteration 1200 / 1500: loss 2.083202
# iteration 1300 / 1500: loss 2.080302
# iteration 1400 / 1500: loss 2.133449
# Choose lr = 4.000000e-07 ,reg = 3.500000e+04
# Train acc = 0.313673, Val acc = 0.328000
# ---------------------No.22iter-----------------------
# iteration 0 / 1500: loss 1208.898909
# iteration 100 / 1500: loss 3.877646
# iteration 200 / 1500: loss 2.131150
# iteration 300 / 1500: loss 2.142661
# iteration 400 / 1500: loss 2.159024
# iteration 500 / 1500: loss 2.108326
# iteration 600 / 1500: loss 2.137407
# iteration 700 / 1500: loss 2.165520
# iteration 800 / 1500: loss 2.148067
# iteration 900 / 1500: loss 2.065093
# iteration 1000 / 1500: loss 2.132560
# iteration 1100 / 1500: loss 2.145275
# iteration 1200 / 1500: loss 2.129945
# iteration 1300 / 1500: loss 2.152250
# iteration 1400 / 1500: loss 2.202169
# Choose lr = 4.000000e-07 ,reg = 4.000000e+04
# Train acc = 0.302816, Val acc = 0.320000
# ---------------------No.23iter-----------------------
# iteration 0 / 1500: loss 1379.409010
# iteration 100 / 1500: loss 3.032953
# iteration 200 / 1500: loss 2.106054
# iteration 300 / 1500: loss 2.114586
# iteration 400 / 1500: loss 2.142736
# iteration 500 / 1500: loss 2.115180
# iteration 600 / 1500: loss 2.069686
# iteration 700 / 1500: loss 2.131872
# iteration 800 / 1500: loss 2.129953
# iteration 900 / 1500: loss 2.115808
# iteration 1000 / 1500: loss 2.153943
# iteration 1100 / 1500: loss 2.112956
# iteration 1200 / 1500: loss 2.143448
# iteration 1300 / 1500: loss 2.136458
# iteration 1400 / 1500: loss 2.119421
# Choose lr = 4.000000e-07 ,reg = 4.500000e+04
# Train acc = 0.316367, Val acc = 0.336000
# ---------------------No.24iter-----------------------
# iteration 0 / 1500: loss 1527.600189
# iteration 100 / 1500: loss 2.612591
# iteration 200 / 1500: loss 2.162743
# iteration 300 / 1500: loss 2.163364
# iteration 400 / 1500: loss 2.205539
# iteration 500 / 1500: loss 2.106416
# iteration 600 / 1500: loss 2.145615
# iteration 700 / 1500: loss 2.163271
# iteration 800 / 1500: loss 2.100352
# iteration 900 / 1500: loss 2.193602
# iteration 1000 / 1500: loss 2.136958
# iteration 1100 / 1500: loss 2.161757
# iteration 1200 / 1500: loss 2.171207
# iteration 1300 / 1500: loss 2.148935
# iteration 1400 / 1500: loss 2.118254
# Choose lr = 4.000000e-07 ,reg = 5.000000e+04
# Train acc = 0.292041, Val acc = 0.309000
# ---------------------No.25iter-----------------------
# iteration 0 / 1500: loss 772.657946
# iteration 100 / 1500: loss 6.933443
# iteration 200 / 1500: loss 2.172168
# iteration 300 / 1500: loss 2.141367
# iteration 400 / 1500: loss 2.031818
# iteration 500 / 1500: loss 2.065023
# iteration 600 / 1500: loss 2.078262
# iteration 700 / 1500: loss 2.091919
# iteration 800 / 1500: loss 2.145357
# iteration 900 / 1500: loss 2.128409
# iteration 1000 / 1500: loss 2.159718
# iteration 1100 / 1500: loss 2.126774
# iteration 1200 / 1500: loss 2.130467
# iteration 1300 / 1500: loss 2.070316
# iteration 1400 / 1500: loss 2.061143
# Choose lr = 5.000000e-07 ,reg = 2.500000e+04
# Train acc = 0.321796, Val acc = 0.333000
# ---------------------No.26iter-----------------------
# iteration 0 / 1500: loss 926.079147
# iteration 100 / 1500: loss 4.170050
# iteration 200 / 1500: loss 2.072398
# iteration 300 / 1500: loss 2.170013
# iteration 400 / 1500: loss 2.054653
# iteration 500 / 1500: loss 2.079494
# iteration 600 / 1500: loss 2.122611
# iteration 700 / 1500: loss 2.100080
# iteration 800 / 1500: loss 2.129874
# iteration 900 / 1500: loss 2.140799
# iteration 1000 / 1500: loss 2.081678
# iteration 1100 / 1500: loss 2.088951
# iteration 1200 / 1500: loss 2.127191
# iteration 1300 / 1500: loss 2.148395
# iteration 1400 / 1500: loss 2.071066
# Choose lr = 5.000000e-07 ,reg = 3.000000e+04
# Train acc = 0.323612, Val acc = 0.336000
# ---------------------No.27iter-----------------------
# iteration 0 / 1500: loss 1073.148565
# iteration 100 / 1500: loss 2.965924
# iteration 200 / 1500: loss 2.157436
# iteration 300 / 1500: loss 2.103283
# iteration 400 / 1500: loss 2.089210
# iteration 500 / 1500: loss 2.128898
# iteration 600 / 1500: loss 2.144062
# iteration 700 / 1500: loss 2.135469
# iteration 800 / 1500: loss 2.173818
# iteration 900 / 1500: loss 2.097832
# iteration 1000 / 1500: loss 2.151116
# iteration 1100 / 1500: loss 2.132357
# iteration 1200 / 1500: loss 2.092265
# iteration 1300 / 1500: loss 2.091011
# iteration 1400 / 1500: loss 2.132786
# Choose lr = 5.000000e-07 ,reg = 3.500000e+04
# Train acc = 0.314857, Val acc = 0.321000
# ---------------------No.28iter-----------------------
# iteration 0 / 1500: loss 1223.001359
# iteration 100 / 1500: loss 2.483981
# iteration 200 / 1500: loss 2.087118
# iteration 300 / 1500: loss 2.104469
# iteration 400 / 1500: loss 2.108404
# iteration 500 / 1500: loss 2.098693
# iteration 600 / 1500: loss 2.140496
# iteration 700 / 1500: loss 2.141876
# iteration 800 / 1500: loss 2.139783
# iteration 900 / 1500: loss 2.162092
# iteration 1000 / 1500: loss 2.136901
# iteration 1100 / 1500: loss 2.101221
# iteration 1200 / 1500: loss 2.087884
# iteration 1300 / 1500: loss 2.116910
# iteration 1400 / 1500: loss 2.042791
# Choose lr = 5.000000e-07 ,reg = 4.000000e+04
# Train acc = 0.297102, Val acc = 0.305000
# ---------------------No.29iter-----------------------
# iteration 0 / 1500: loss 1392.809772
# iteration 100 / 1500: loss 2.294377
# iteration 200 / 1500: loss 2.115485
# iteration 300 / 1500: loss 2.124583
# iteration 400 / 1500: loss 2.124806
# iteration 500 / 1500: loss 2.135601
# iteration 600 / 1500: loss 2.136573
# iteration 700 / 1500: loss 2.106082
# iteration 800 / 1500: loss 2.139896
# iteration 900 / 1500: loss 2.131604
# iteration 1000 / 1500: loss 2.117398
# iteration 1100 / 1500: loss 2.119941
# iteration 1200 / 1500: loss 2.155625
# iteration 1300 / 1500: loss 2.129402
# iteration 1400 / 1500: loss 2.161941
# Choose lr = 5.000000e-07 ,reg = 4.500000e+04
# Train acc = 0.296673, Val acc = 0.313000
# ---------------------No.30iter-----------------------
# iteration 0 / 1500: loss 1540.476346
# iteration 100 / 1500: loss 2.175396
# iteration 200 / 1500: loss 2.126002
# iteration 300 / 1500: loss 2.110995
# iteration 400 / 1500: loss 2.180194
# iteration 500 / 1500: loss 2.185109
# iteration 600 / 1500: loss 2.138918
# iteration 700 / 1500: loss 2.132888
# iteration 800 / 1500: loss 2.092171
# iteration 900 / 1500: loss 2.185548
# iteration 1000 / 1500: loss 2.180695
# iteration 1100 / 1500: loss 2.142737
# iteration 1200 / 1500: loss 2.203290
# iteration 1300 / 1500: loss 2.118932
# iteration 1400 / 1500: loss 2.130452
# Choose lr = 5.000000e-07 ,reg = 5.000000e+04
# Train acc = 0.295653, Val acc = 0.312000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.329694 val accuracy: 0.344000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.329143 val accuracy: 0.343000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.312837 val accuracy: 0.330000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.316102 val accuracy: 0.330000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.305714 val accuracy: 0.319000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.304490 val accuracy: 0.316000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.330816 val accuracy: 0.346000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.320184 val accuracy: 0.343000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.312633 val accuracy: 0.333000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.316184 val accuracy: 0.337000
# lr 2.000000e-07 reg 4.500000e+04 train accuracy: 0.294449 val accuracy: 0.310000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.301510 val accuracy: 0.314000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.328918 val accuracy: 0.344000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.315265 val accuracy: 0.329000
# lr 3.000000e-07 reg 3.500000e+04 train accuracy: 0.313592 val accuracy: 0.325000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.306796 val accuracy: 0.326000
# lr 3.000000e-07 reg 4.500000e+04 train accuracy: 0.306184 val accuracy: 0.325000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.304571 val accuracy: 0.323000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.324388 val accuracy: 0.342000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.322020 val accuracy: 0.337000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.313673 val accuracy: 0.328000
# lr 4.000000e-07 reg 4.000000e+04 train accuracy: 0.302816 val accuracy: 0.320000
# lr 4.000000e-07 reg 4.500000e+04 train accuracy: 0.316367 val accuracy: 0.336000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.292041 val accuracy: 0.309000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.321796 val accuracy: 0.333000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.323612 val accuracy: 0.336000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.314857 val accuracy: 0.321000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.297102 val accuracy: 0.305000
# lr 5.000000e-07 reg 4.500000e+04 train accuracy: 0.296673 val accuracy: 0.313000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.295653 val accuracy: 0.312000
# best validation accuracy achieved during cross-validation: 0.346000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.334000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
